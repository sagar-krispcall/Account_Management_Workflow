# %%
import requests
import json
import csv
import re
from typing import Optional, Dict, Any, List
from pathlib import Path

import phonenumbers
from phonenumbers import geocoder

from dotenv import load_dotenv
import os

# Load environment variables from .env file
load_dotenv()

# %%
PIPEDRIVE_COMPANY_DOMAIN = os.getenv("PIPEDRIVE_COMPANY_DOMAIN")
PIPEDRIVE_API_TOKEN = os.getenv("PIPEDRIVE_API_TOKEN")

LIMIT = 500

DEFAULT_REGION = "US"   # used only if a phone has no +country code, change if needed

OUTPUT_JSON = Path("persons_page_1.json")
OUTPUT_CSV = Path("pipedrive_contacts_all.csv")

# %%
EMAIL_REGEX = re.compile(r"^[^@\s]+@[^@\s]+\.[^@\s]+$")

def is_valid_email(value: str) -> bool:
    if not value:
        return False
    value = value.strip()
    if len(value) < 5 or len(value) > 254:
        return False
    return bool(EMAIL_REGEX.match(value))

def pick_email(person: Dict[str, Any]) -> Optional[str]:
    """Pick a valid email from person['emails'], preferring primary."""
    emails = person.get("emails") or []
    if not isinstance(emails, list):
        return None

    primary_candidate = None
    other_candidates: List[str] = []

    for item in emails:
        if not isinstance(item, dict):
            continue
        raw = item.get("value")
        if not isinstance(raw, str):
            continue
        val = raw.strip()
        if not val:
            continue

        if item.get("primary") and is_valid_email(val):
            primary_candidate = val
            break
        elif is_valid_email(val):
            other_candidates.append(val)

    if primary_candidate:
        return primary_candidate
    if other_candidates:
        return other_candidates[0]
    return None

# %%
def normalize_phone(raw: str) -> Optional[str]:
    """
    Clean obvious junk in phone numbers.

    Examples:
      '++918521225200' -> '+918521225200'
      ' +91 8521-225-200 ' -> '+918521225200'
    """
    if not raw:
        return None
    s = str(raw).strip()

    # Collapse multiple leading '+' into a single '+'
    while s.startswith("++"):
        s = s[1:]

    cleaned_chars = []
    for ch in s:
        if ch.isdigit():
            cleaned_chars.append(ch)
        elif ch == "+" and not cleaned_chars:
            cleaned_chars.append(ch)

    if not cleaned_chars:
        return None

    cleaned = "".join(cleaned_chars)
    return cleaned if cleaned else None


def detect_country_full_name(phone: str, default_region: str = DEFAULT_REGION) -> Optional[str]:
    """Return full country name using phonenumbers geocoder."""
    if not phone:
        return None
    try:
        if phone.startswith("+"):
            num = phonenumbers.parse(phone, None)
        else:
            num = phonenumbers.parse(phone, default_region)

        if not phonenumbers.is_valid_number(num):
            return None

        country_name = geocoder.description_for_number(num, "en")
        return country_name or None
    except phonenumbers.NumberParseException:
        return None


def pick_phone(person: Dict[str, Any]) -> Optional[str]:
    """
    Pick a valid phone from person['phones'], preferring primary.
    Only accept numbers that parse as valid.
    """
    phones = person.get("phones") or []
    if not isinstance(phones, list):
        return None

    primary_candidate = None
    other_candidates: List[str] = []

    for item in phones:
        if not isinstance(item, dict):
            continue
        raw = item.get("value")
        if not isinstance(raw, str):
            continue

        normalized = normalize_phone(raw)
        if not normalized:
            continue

        if len(normalized.replace("+", "")) < 5:
            continue

        # Check if this number is valid and has a country
        country = detect_country_full_name(normalized)
        if country:
            if item.get("primary"):
                primary_candidate = normalized
                break
            else:
                other_candidates.append(normalized)

    if primary_candidate:
        return primary_candidate
    if other_candidates:
        return other_candidates[0]
    return None

# %%
def fetch_person_page(cursor: Optional[str] = None, limit: int = LIMIT) -> Dict[str, Any]:
    """Call Pipedrive v2 persons API for one page."""
    if not PIPEDRIVE_COMPANY_DOMAIN or not PIPEDRIVE_API_TOKEN:
        raise RuntimeError("Please set PIPEDRIVE_COMPANY_DOMAIN and PIPEDRIVE_API_TOKEN in the config section.")

    url = f"https://{PIPEDRIVE_COMPANY_DOMAIN}.pipedrive.com/api/v2/persons"
    headers = {
        "Accept": "application/json",
        "x-api-token": PIPEDRIVE_API_TOKEN
    }
    params = {"limit": limit}
    if cursor:
        params["cursor"] = cursor

    print(f"Requesting up to {limit} persons. cursor={cursor}")
    res = requests.get(url, headers=headers, params=params, timeout=60)
    try:
        res.raise_for_status()
    except requests.HTTPError as e:
        print("Error from Pipedrive API")
        print("Status code:", res.status_code)
        print("Body:", res.text)
        raise e

    return res.json()

# %%
all_rows: List[Dict[str, str]] = []

cursor = None
page = 1

total_raw = 0
total_kept = 0
total_skipped_missing = 0

while True:
    payload = fetch_person_page(cursor=cursor, limit=LIMIT)
    persons = payload.get("data") or []
    additional = payload.get("additional_data") or {}
    cursor = additional.get("next_cursor")

    if not persons:
        print("No more persons in response. stopping.")
        break

    total_raw += len(persons)

    for p in persons:
        email = pick_email(p)
        phone = pick_phone(p)

        # Drop people with missing email or phone
        if not email or not phone:
            total_skipped_missing += 1
            continue

        country_name = detect_country_full_name(phone) or ""

        all_rows.append({
            "email": email,
            "phone": phone,
            "phone_country": country_name
        })
        total_kept += 1

    print(
        f"Processed page {page}. "
        f"persons in page: {len(persons)}. "
        f"kept so far: {total_kept}. "
        f"skipped (missing email/phone) so far: {total_skipped_missing}. "
        f"next_cursor: {cursor}"
    )

    page += 1

    if not cursor:
        print("No next_cursor. reached final page.")
        break

# Write final CSV
with OUTPUT_CSV.open("w", encoding="utf-8", newline="") as f:
    writer = csv.DictWriter(f, fieldnames=["email", "phone", "phone_country"])
    writer.writeheader()
    writer.writerows(all_rows)

print("\n=== DONE ===")
print(f"Total persons returned by API: {total_raw}")
print(f"Total kept (both email and phone present): {total_kept}")
print(f"Total dropped (missing email or phone): {total_skipped_missing}")
print(f"CSV written to: {OUTPUT_CSV.resolve()}")

# Quick preview of first 5 rows
for row in all_rows[:5]:
    print(row)
# Out:
# Requesting up to 500 persons. cursor=None
# Processed page 1. persons in page: 500. kept so far: 443. skipped (missing email/phone) so far: 57. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTQ5LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjU0OX0
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTQ5LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjU0OX0
# Processed page 2. persons in page: 500. kept so far: 883. skipped (missing email/phone) so far: 117. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTA1MCwic29ydERpcmVjdGlvbiI6ImFzYyIsImlkIjoxMDUwfQ
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTA1MCwic29ydERpcmVjdGlvbiI6ImFzYyIsImlkIjoxMDUwfQ
# Processed page 3. persons in page: 500. kept so far: 1334. skipped (missing email/phone) so far: 166. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTU1MCwic29ydERpcmVjdGlvbiI6ImFzYyIsImlkIjoxNTUwfQ
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTU1MCwic29ydERpcmVjdGlvbiI6ImFzYyIsImlkIjoxNTUwfQ
# Processed page 4. persons in page: 500. kept so far: 1793. skipped (missing email/phone) so far: 207. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MjA1MCwic29ydERpcmVjdGlvbiI6ImFzYyIsImlkIjoyMDUwfQ
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MjA1MCwic29ydERpcmVjdGlvbiI6ImFzYyIsImlkIjoyMDUwfQ
# Processed page 5. persons in page: 500. kept so far: 2246. skipped (missing email/phone) so far: 254. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MjU1Miwic29ydERpcmVjdGlvbiI6ImFzYyIsImlkIjoyNTUyfQ
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MjU1Miwic29ydERpcmVjdGlvbiI6ImFzYyIsImlkIjoyNTUyfQ
# Processed page 6. persons in page: 500. kept so far: 2705. skipped (missing email/phone) so far: 295. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzA1Miwic29ydERpcmVjdGlvbiI6ImFzYyIsImlkIjozMDUyfQ
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzA1Miwic29ydERpcmVjdGlvbiI6ImFzYyIsImlkIjozMDUyfQ
# Processed page 7. persons in page: 500. kept so far: 3170. skipped (missing email/phone) so far: 330. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzU1Miwic29ydERpcmVjdGlvbiI6ImFzYyIsImlkIjozNTUyfQ
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzU1Miwic29ydERpcmVjdGlvbiI6ImFzYyIsImlkIjozNTUyfQ
# Processed page 8. persons in page: 500. kept so far: 3641. skipped (missing email/phone) so far: 359. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDA1Miwic29ydERpcmVjdGlvbiI6ImFzYyIsImlkIjo0MDUyfQ
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDA1Miwic29ydERpcmVjdGlvbiI6ImFzYyIsImlkIjo0MDUyfQ
# Processed page 9. persons in page: 500. kept so far: 4102. skipped (missing email/phone) so far: 398. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDU1Mywic29ydERpcmVjdGlvbiI6ImFzYyIsImlkIjo0NTUzfQ
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDU1Mywic29ydERpcmVjdGlvbiI6ImFzYyIsImlkIjo0NTUzfQ
# Processed page 10. persons in page: 500. kept so far: 4536. skipped (missing email/phone) so far: 464. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTA1Mywic29ydERpcmVjdGlvbiI6ImFzYyIsImlkIjo1MDUzfQ
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTA1Mywic29ydERpcmVjdGlvbiI6ImFzYyIsImlkIjo1MDUzfQ
# Processed page 11. persons in page: 500. kept so far: 4986. skipped (missing email/phone) so far: 514. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTU1Mywic29ydERpcmVjdGlvbiI6ImFzYyIsImlkIjo1NTUzfQ
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTU1Mywic29ydERpcmVjdGlvbiI6ImFzYyIsImlkIjo1NTUzfQ
# Processed page 12. persons in page: 500. kept so far: 5428. skipped (missing email/phone) so far: 572. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NjA1NCwic29ydERpcmVjdGlvbiI6ImFzYyIsImlkIjo2MDU0fQ
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NjA1NCwic29ydERpcmVjdGlvbiI6ImFzYyIsImlkIjo2MDU0fQ
# Processed page 13. persons in page: 500. kept so far: 5882. skipped (missing email/phone) so far: 618. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NjU1NCwic29ydERpcmVjdGlvbiI6ImFzYyIsImlkIjo2NTU0fQ
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NjU1NCwic29ydERpcmVjdGlvbiI6ImFzYyIsImlkIjo2NTU0fQ
# Processed page 14. persons in page: 500. kept so far: 6338. skipped (missing email/phone) so far: 662. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NzA1NSwic29ydERpcmVjdGlvbiI6ImFzYyIsImlkIjo3MDU1fQ
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NzA1NSwic29ydERpcmVjdGlvbiI6ImFzYyIsImlkIjo3MDU1fQ
# Processed page 15. persons in page: 500. kept so far: 6770. skipped (missing email/phone) so far: 730. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NzU1Niwic29ydERpcmVjdGlvbiI6ImFzYyIsImlkIjo3NTU2fQ
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NzU1Niwic29ydERpcmVjdGlvbiI6ImFzYyIsImlkIjo3NTU2fQ
# Processed page 16. persons in page: 500. kept so far: 7213. skipped (missing email/phone) so far: 787. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6ODA1OCwic29ydERpcmVjdGlvbiI6ImFzYyIsImlkIjo4MDU4fQ
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6ODA1OCwic29ydERpcmVjdGlvbiI6ImFzYyIsImlkIjo4MDU4fQ
# Processed page 17. persons in page: 500. kept so far: 7643. skipped (missing email/phone) so far: 857. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6ODU2MCwic29ydERpcmVjdGlvbiI6ImFzYyIsImlkIjo4NTYwfQ
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6ODU2MCwic29ydERpcmVjdGlvbiI6ImFzYyIsImlkIjo4NTYwfQ
# Processed page 18. persons in page: 500. kept so far: 8079. skipped (missing email/phone) so far: 921. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6OTA2MCwic29ydERpcmVjdGlvbiI6ImFzYyIsImlkIjo5MDYwfQ
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6OTA2MCwic29ydERpcmVjdGlvbiI6ImFzYyIsImlkIjo5MDYwfQ
# Processed page 19. persons in page: 500. kept so far: 8528. skipped (missing email/phone) so far: 972. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6OTU2MCwic29ydERpcmVjdGlvbiI6ImFzYyIsImlkIjo5NTYwfQ
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6OTU2MCwic29ydERpcmVjdGlvbiI6ImFzYyIsImlkIjo5NTYwfQ
# Processed page 20. persons in page: 500. kept so far: 8972. skipped (missing email/phone) so far: 1028. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTAwNjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTAwNjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTAwNjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTAwNjB9
# Processed page 21. persons in page: 500. kept so far: 9415. skipped (missing email/phone) so far: 1085. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTA1NjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTA1NjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTA1NjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTA1NjB9
# Processed page 22. persons in page: 500. kept so far: 9862. skipped (missing email/phone) so far: 1138. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTEwNjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTEwNjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTEwNjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTEwNjB9
# Processed page 23. persons in page: 500. kept so far: 10299. skipped (missing email/phone) so far: 1201. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTE1NjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTE1NjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTE1NjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTE1NjB9
# Processed page 24. persons in page: 500. kept so far: 10747. skipped (missing email/phone) so far: 1253. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTIwNjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTIwNjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTIwNjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTIwNjB9
# Processed page 25. persons in page: 500. kept so far: 11199. skipped (missing email/phone) so far: 1301. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTI1NjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTI1NjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTI1NjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTI1NjB9
# Processed page 26. persons in page: 500. kept so far: 11659. skipped (missing email/phone) so far: 1341. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTMwNjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTMwNjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTMwNjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTMwNjB9
# Processed page 27. persons in page: 500. kept so far: 12118. skipped (missing email/phone) so far: 1382. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTM1NjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTM1NjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTM1NjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTM1NjB9
# Processed page 28. persons in page: 500. kept so far: 12567. skipped (missing email/phone) so far: 1433. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTQwNjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTQwNjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTQwNjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTQwNjB9
# Processed page 29. persons in page: 500. kept so far: 13016. skipped (missing email/phone) so far: 1484. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTQ1NjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTQ1NjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTQ1NjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTQ1NjB9
# Processed page 30. persons in page: 500. kept so far: 13463. skipped (missing email/phone) so far: 1537. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTUwNjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTUwNjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTUwNjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTUwNjB9
# Processed page 31. persons in page: 500. kept so far: 13909. skipped (missing email/phone) so far: 1591. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTU1NjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTU1NjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTU1NjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTU1NjB9
# Processed page 32. persons in page: 500. kept so far: 14360. skipped (missing email/phone) so far: 1640. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTYwNjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTYwNjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTYwNjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTYwNjB9
# Processed page 33. persons in page: 500. kept so far: 14820. skipped (missing email/phone) so far: 1680. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTY1NjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTY1NjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTY1NjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTY1NjB9
# Processed page 34. persons in page: 500. kept so far: 15255. skipped (missing email/phone) so far: 1745. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTcwNjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTcwNjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTcwNjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTcwNjB9
# Processed page 35. persons in page: 500. kept so far: 15705. skipped (missing email/phone) so far: 1795. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTc1NjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTc1NjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTc1NjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTc1NjB9
# Processed page 36. persons in page: 500. kept so far: 16138. skipped (missing email/phone) so far: 1862. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTgwNjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTgwNjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTgwNjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTgwNjB9
# Processed page 37. persons in page: 500. kept so far: 16364. skipped (missing email/phone) so far: 2136. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTg1NjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTg1NjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTg1NjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTg1NjB9
# Processed page 38. persons in page: 500. kept so far: 16783. skipped (missing email/phone) so far: 2217. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTkwNjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTkwNjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTkwNjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTkwNjB9
# Processed page 39. persons in page: 500. kept so far: 17223. skipped (missing email/phone) so far: 2277. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTk1NjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTk1NjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MTk1NjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MTk1NjB9
# Processed page 40. persons in page: 500. kept so far: 17655. skipped (missing email/phone) so far: 2345. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MjAwNjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MjAwNjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MjAwNjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MjAwNjB9
# Processed page 41. persons in page: 500. kept so far: 18072. skipped (missing email/phone) so far: 2428. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MjA1NjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MjA1NjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MjA1NjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MjA1NjB9
# Processed page 42. persons in page: 500. kept so far: 18498. skipped (missing email/phone) so far: 2502. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MjEwNjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MjEwNjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MjEwNjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MjEwNjB9
# Processed page 43. persons in page: 500. kept so far: 18925. skipped (missing email/phone) so far: 2575. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MjE1NjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MjE1NjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MjE1NjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MjE1NjB9
# Processed page 44. persons in page: 500. kept so far: 19332. skipped (missing email/phone) so far: 2668. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MjIwNjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MjIwNjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MjIwNjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MjIwNjB9
# Processed page 45. persons in page: 500. kept so far: 19752. skipped (missing email/phone) so far: 2748. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MjI1NjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MjI1NjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MjI1NjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MjI1NjB9
# Processed page 46. persons in page: 500. kept so far: 20190. skipped (missing email/phone) so far: 2810. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MjMwNjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MjMwNjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MjMwNjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MjMwNjB9
# Processed page 47. persons in page: 500. kept so far: 20632. skipped (missing email/phone) so far: 2868. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MjM1NjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MjM1NjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MjM1NjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MjM1NjB9
# Processed page 48. persons in page: 500. kept so far: 21068. skipped (missing email/phone) so far: 2932. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MjQwNjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MjQwNjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MjQwNjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MjQwNjB9
# Processed page 49. persons in page: 500. kept so far: 21510. skipped (missing email/phone) so far: 2990. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MjQ1NjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MjQ1NjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MjQ1NjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MjQ1NjB9
# Processed page 50. persons in page: 500. kept so far: 21904. skipped (missing email/phone) so far: 3096. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MjUwNjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MjUwNjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MjUwNjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MjUwNjB9
# Processed page 51. persons in page: 500. kept so far: 22326. skipped (missing email/phone) so far: 3174. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MjU1NjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MjU1NjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MjU1NjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MjU1NjB9
# Processed page 52. persons in page: 500. kept so far: 22726. skipped (missing email/phone) so far: 3274. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MjYwNjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MjYwNjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MjYwNjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MjYwNjB9
# Processed page 53. persons in page: 500. kept so far: 23165. skipped (missing email/phone) so far: 3335. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MjY1NjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MjY1NjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MjY1NjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MjY1NjB9
# Processed page 54. persons in page: 500. kept so far: 23621. skipped (missing email/phone) so far: 3379. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MjcwNjEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MjcwNjF9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MjcwNjEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MjcwNjF9
# Processed page 55. persons in page: 500. kept so far: 24079. skipped (missing email/phone) so far: 3421. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6Mjc1NjEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6Mjc1NjF9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6Mjc1NjEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6Mjc1NjF9
# Processed page 56. persons in page: 500. kept so far: 24526. skipped (missing email/phone) so far: 3474. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MjgwNjEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MjgwNjF9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MjgwNjEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MjgwNjF9
# Processed page 57. persons in page: 500. kept so far: 24946. skipped (missing email/phone) so far: 3554. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6Mjg1NjEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6Mjg1NjF9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6Mjg1NjEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6Mjg1NjF9
# Processed page 58. persons in page: 500. kept so far: 25386. skipped (missing email/phone) so far: 3614. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MjkwNjEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MjkwNjF9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MjkwNjEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MjkwNjF9
# Processed page 59. persons in page: 500. kept so far: 25826. skipped (missing email/phone) so far: 3674. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6Mjk1NjEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6Mjk1NjF9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6Mjk1NjEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6Mjk1NjF9
# Processed page 60. persons in page: 500. kept so far: 26274. skipped (missing email/phone) so far: 3726. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzAwNjEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MzAwNjF9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzAwNjEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MzAwNjF9
# Processed page 61. persons in page: 500. kept so far: 26394. skipped (missing email/phone) so far: 4106. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzA1NjEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MzA1NjF9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzA1NjEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MzA1NjF9
# Processed page 62. persons in page: 500. kept so far: 26426. skipped (missing email/phone) so far: 4574. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzEwNjEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MzEwNjF9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzEwNjEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MzEwNjF9
# Processed page 63. persons in page: 500. kept so far: 26877. skipped (missing email/phone) so far: 4623. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzE1NjEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MzE1NjF9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzE1NjEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MzE1NjF9
# Processed page 64. persons in page: 500. kept so far: 27324. skipped (missing email/phone) so far: 4676. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzIwNjEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MzIwNjF9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzIwNjEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MzIwNjF9
# Processed page 65. persons in page: 500. kept so far: 27752. skipped (missing email/phone) so far: 4748. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzI1NjIsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MzI1NjJ9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzI1NjIsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MzI1NjJ9
# Processed page 66. persons in page: 500. kept so far: 28196. skipped (missing email/phone) so far: 4804. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzMwNjIsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MzMwNjJ9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzMwNjIsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MzMwNjJ9
# Processed page 67. persons in page: 500. kept so far: 28637. skipped (missing email/phone) so far: 4863. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzM1NjMsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MzM1NjN9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzM1NjMsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MzM1NjN9
# Processed page 68. persons in page: 500. kept so far: 29078. skipped (missing email/phone) so far: 4922. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzQwNjMsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MzQwNjN9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzQwNjMsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MzQwNjN9
# Processed page 69. persons in page: 500. kept so far: 29506. skipped (missing email/phone) so far: 4994. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzQ1NjUsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MzQ1NjV9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzQ1NjUsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MzQ1NjV9
# Processed page 70. persons in page: 500. kept so far: 29947. skipped (missing email/phone) so far: 5053. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzUwNzAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MzUwNzB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzUwNzAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MzUwNzB9
# Processed page 71. persons in page: 500. kept so far: 30388. skipped (missing email/phone) so far: 5112. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzU1NzAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MzU1NzB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzU1NzAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MzU1NzB9
# Processed page 72. persons in page: 500. kept so far: 30840. skipped (missing email/phone) so far: 5160. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzYwNzAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MzYwNzB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzYwNzAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MzYwNzB9
# Processed page 73. persons in page: 500. kept so far: 31286. skipped (missing email/phone) so far: 5214. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzY1NzAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MzY1NzB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzY1NzAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MzY1NzB9
# Processed page 74. persons in page: 500. kept so far: 31736. skipped (missing email/phone) so far: 5264. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzcxMDcsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MzcxMDd9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzcxMDcsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MzcxMDd9
# Processed page 75. persons in page: 500. kept so far: 32181. skipped (missing email/phone) so far: 5319. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6Mzc2MDcsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6Mzc2MDd9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6Mzc2MDcsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6Mzc2MDd9
# Processed page 76. persons in page: 500. kept so far: 32611. skipped (missing email/phone) so far: 5389. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzgxMDcsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MzgxMDd9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzgxMDcsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MzgxMDd9
# Processed page 77. persons in page: 500. kept so far: 33046. skipped (missing email/phone) so far: 5454. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6Mzg2MDcsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6Mzg2MDd9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6Mzg2MDcsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6Mzg2MDd9
# Processed page 78. persons in page: 500. kept so far: 33501. skipped (missing email/phone) so far: 5499. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzkxMDcsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MzkxMDd9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzkxMDcsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6MzkxMDd9
# Processed page 79. persons in page: 500. kept so far: 33959. skipped (missing email/phone) so far: 5541. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6Mzk2MDcsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6Mzk2MDd9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6Mzk2MDcsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6Mzk2MDd9
# Processed page 80. persons in page: 500. kept so far: 34412. skipped (missing email/phone) so far: 5588. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDAxMDcsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDAxMDd9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDAxMDcsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDAxMDd9
# Processed page 81. persons in page: 500. kept so far: 34858. skipped (missing email/phone) so far: 5642. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDA2MDcsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDA2MDd9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDA2MDcsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDA2MDd9
# Processed page 82. persons in page: 500. kept so far: 35269. skipped (missing email/phone) so far: 5731. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDExMDksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDExMDl9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDExMDksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDExMDl9
# Processed page 83. persons in page: 500. kept so far: 35726. skipped (missing email/phone) so far: 5774. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDE2MDksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDE2MDl9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDE2MDksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDE2MDl9
# Processed page 84. persons in page: 500. kept so far: 36165. skipped (missing email/phone) so far: 5835. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDIxMDksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDIxMDl9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDIxMDksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDIxMDl9
# Processed page 85. persons in page: 500. kept so far: 36619. skipped (missing email/phone) so far: 5881. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDI2MDksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDI2MDl9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDI2MDksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDI2MDl9
# Processed page 86. persons in page: 500. kept so far: 37082. skipped (missing email/phone) so far: 5918. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDMxMDksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDMxMDl9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDMxMDksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDMxMDl9
# Processed page 87. persons in page: 500. kept so far: 37535. skipped (missing email/phone) so far: 5965. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDM2MDksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDM2MDl9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDM2MDksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDM2MDl9
# Processed page 88. persons in page: 500. kept so far: 37997. skipped (missing email/phone) so far: 6003. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDQxMDksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDQxMDl9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDQxMDksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDQxMDl9
# Processed page 89. persons in page: 500. kept so far: 38380. skipped (missing email/phone) so far: 6120. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDQ2MDksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDQ2MDl9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDQ2MDksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDQ2MDl9
# Processed page 90. persons in page: 500. kept so far: 38636. skipped (missing email/phone) so far: 6364. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDUxMDksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDUxMDl9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDUxMDksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDUxMDl9
# Processed page 91. persons in page: 500. kept so far: 38839. skipped (missing email/phone) so far: 6661. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDU2MTAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDU2MTB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDU2MTAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDU2MTB9
# Processed page 92. persons in page: 500. kept so far: 38954. skipped (missing email/phone) so far: 7046. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDYxMTAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDYxMTB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDYxMTAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDYxMTB9
# Processed page 93. persons in page: 500. kept so far: 39006. skipped (missing email/phone) so far: 7494. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDY2MTEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDY2MTF9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDY2MTEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDY2MTF9
# Processed page 94. persons in page: 500. kept so far: 39109. skipped (missing email/phone) so far: 7891. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDcxMTEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDcxMTF9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDcxMTEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDcxMTF9
# Processed page 95. persons in page: 500. kept so far: 39385. skipped (missing email/phone) so far: 8115. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDc2MTEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDc2MTF9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDc2MTEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDc2MTF9
# Processed page 96. persons in page: 500. kept so far: 39822. skipped (missing email/phone) so far: 8178. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDgxMTEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDgxMTF9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDgxMTEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDgxMTF9
# Processed page 97. persons in page: 500. kept so far: 40263. skipped (missing email/phone) so far: 8237. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDg2MTEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDg2MTF9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDg2MTEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDg2MTF9
# Processed page 98. persons in page: 500. kept so far: 40693. skipped (missing email/phone) so far: 8307. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDkxMTEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDkxMTF9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDkxMTEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDkxMTF9
# Processed page 99. persons in page: 500. kept so far: 41125. skipped (missing email/phone) so far: 8375. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDk2MTEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDk2MTF9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NDk2MTEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NDk2MTF9
# Processed page 100. persons in page: 500. kept so far: 41553. skipped (missing email/phone) so far: 8447. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTAxMTEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTAxMTF9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTAxMTEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTAxMTF9
# Processed page 101. persons in page: 500. kept so far: 41993. skipped (missing email/phone) so far: 8507. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTA2MTEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTA2MTF9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTA2MTEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTA2MTF9
# Processed page 102. persons in page: 500. kept so far: 42430. skipped (missing email/phone) so far: 8570. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTExMTIsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTExMTJ9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTExMTIsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTExMTJ9
# Processed page 103. persons in page: 500. kept so far: 42858. skipped (missing email/phone) so far: 8642. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTE2MTIsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTE2MTJ9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTE2MTIsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTE2MTJ9
# Processed page 104. persons in page: 500. kept so far: 43303. skipped (missing email/phone) so far: 8697. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTIxMTMsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTIxMTN9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTIxMTMsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTIxMTN9
# Processed page 105. persons in page: 500. kept so far: 43746. skipped (missing email/phone) so far: 8754. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTI2MTMsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTI2MTN9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTI2MTMsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTI2MTN9
# Processed page 106. persons in page: 500. kept so far: 44179. skipped (missing email/phone) so far: 8821. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTMxMTQsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTMxMTR9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTMxMTQsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTMxMTR9
# Processed page 107. persons in page: 500. kept so far: 44604. skipped (missing email/phone) so far: 8896. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTM2MTQsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTM2MTR9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTM2MTQsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTM2MTR9
# Processed page 108. persons in page: 500. kept so far: 45051. skipped (missing email/phone) so far: 8949. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTQxMTQsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTQxMTR9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTQxMTQsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTQxMTR9
# Processed page 109. persons in page: 500. kept so far: 45484. skipped (missing email/phone) so far: 9016. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTQ2MTQsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTQ2MTR9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTQ2MTQsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTQ2MTR9
# Processed page 110. persons in page: 500. kept so far: 45922. skipped (missing email/phone) so far: 9078. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTUxMTQsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTUxMTR9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTUxMTQsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTUxMTR9
# Processed page 111. persons in page: 500. kept so far: 46349. skipped (missing email/phone) so far: 9151. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTU2MTUsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTU2MTV9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTU2MTUsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTU2MTV9
# Processed page 112. persons in page: 500. kept so far: 46791. skipped (missing email/phone) so far: 9209. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTYxMTYsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTYxMTZ9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTYxMTYsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTYxMTZ9
# Processed page 113. persons in page: 500. kept so far: 47225. skipped (missing email/phone) so far: 9275. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTY2MTYsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTY2MTZ9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTY2MTYsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTY2MTZ9
# Processed page 114. persons in page: 500. kept so far: 47653. skipped (missing email/phone) so far: 9347. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTcxMTYsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTcxMTZ9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTcxMTYsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTcxMTZ9
# Processed page 115. persons in page: 500. kept so far: 48102. skipped (missing email/phone) so far: 9398. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTc2MTcsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTc2MTd9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTc2MTcsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTc2MTd9
# Processed page 116. persons in page: 500. kept so far: 48531. skipped (missing email/phone) so far: 9469. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTgxMTcsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTgxMTd9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTgxMTcsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTgxMTd9
# Processed page 117. persons in page: 500. kept so far: 48962. skipped (missing email/phone) so far: 9538. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTg2MTcsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTg2MTd9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTg2MTcsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTg2MTd9
# Processed page 118. persons in page: 500. kept so far: 49346. skipped (missing email/phone) so far: 9654. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTkxMTcsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTkxMTd9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTkxMTcsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTkxMTd9
# Processed page 119. persons in page: 500. kept so far: 49748. skipped (missing email/phone) so far: 9752. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTk2MTcsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTk2MTd9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NTk2MTcsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NTk2MTd9
# Processed page 120. persons in page: 500. kept so far: 50208. skipped (missing email/phone) so far: 9792. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NjAxMTcsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NjAxMTd9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NjAxMTcsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NjAxMTd9
# Processed page 121. persons in page: 500. kept so far: 50638. skipped (missing email/phone) so far: 9862. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NjA2MTcsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NjA2MTd9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NjA2MTcsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NjA2MTd9
# Processed page 122. persons in page: 500. kept so far: 51080. skipped (missing email/phone) so far: 9920. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NjExMTcsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NjExMTd9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NjExMTcsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NjExMTd9
# Processed page 123. persons in page: 500. kept so far: 51510. skipped (missing email/phone) so far: 9990. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NjE2MTcsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NjE2MTd9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NjE2MTcsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NjE2MTd9
# Processed page 124. persons in page: 500. kept so far: 51954. skipped (missing email/phone) so far: 10046. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NjIxMTcsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NjIxMTd9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NjIxMTcsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NjIxMTd9
# Processed page 125. persons in page: 500. kept so far: 52393. skipped (missing email/phone) so far: 10107. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NjI2MTksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NjI2MTl9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NjI2MTksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NjI2MTl9
# Processed page 126. persons in page: 500. kept so far: 52831. skipped (missing email/phone) so far: 10169. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NjMxMTksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NjMxMTl9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NjMxMTksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NjMxMTl9
# Processed page 127. persons in page: 500. kept so far: 53271. skipped (missing email/phone) so far: 10229. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NjM2MTksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NjM2MTl9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NjM2MTksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NjM2MTl9
# Processed page 128. persons in page: 500. kept so far: 53730. skipped (missing email/phone) so far: 10270. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NjQxMTksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NjQxMTl9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NjQxMTksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NjQxMTl9
# Processed page 129. persons in page: 500. kept so far: 54176. skipped (missing email/phone) so far: 10324. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NjQ2MTksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NjQ2MTl9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NjQ2MTksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NjQ2MTl9
# Processed page 130. persons in page: 500. kept so far: 54632. skipped (missing email/phone) so far: 10368. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NjUxMTksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NjUxMTl9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NjUxMTksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NjUxMTl9
# Processed page 131. persons in page: 500. kept so far: 55087. skipped (missing email/phone) so far: 10413. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NjU2MTksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NjU2MTl9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NjU2MTksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NjU2MTl9
# Processed page 132. persons in page: 500. kept so far: 55544. skipped (missing email/phone) so far: 10456. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NjYxMTksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NjYxMTl9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NjYxMTksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NjYxMTl9
# Processed page 133. persons in page: 500. kept so far: 56004. skipped (missing email/phone) so far: 10496. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NjY2MTksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NjY2MTl9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NjY2MTksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NjY2MTl9
# Processed page 134. persons in page: 500. kept so far: 56454. skipped (missing email/phone) so far: 10546. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NjcxMTksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NjcxMTl9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NjcxMTksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NjcxMTl9
# Processed page 135. persons in page: 500. kept so far: 56768. skipped (missing email/phone) so far: 10732. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6Njc2MTksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6Njc2MTl9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6Njc2MTksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6Njc2MTl9
# Processed page 136. persons in page: 500. kept so far: 57165. skipped (missing email/phone) so far: 10835. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NjgxMTksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NjgxMTl9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NjgxMTksInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NjgxMTl9
# Processed page 137. persons in page: 500. kept so far: 57587. skipped (missing email/phone) so far: 10913. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6Njg2MjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6Njg2MjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6Njg2MjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6Njg2MjB9
# Processed page 138. persons in page: 500. kept so far: 58033. skipped (missing email/phone) so far: 10967. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NjkxMjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NjkxMjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NjkxMjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NjkxMjB9
# Processed page 139. persons in page: 500. kept so far: 58474. skipped (missing email/phone) so far: 11026. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6Njk2MjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6Njk2MjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6Njk2MjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6Njk2MjB9
# Processed page 140. persons in page: 500. kept so far: 58903. skipped (missing email/phone) so far: 11097. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NzAxMjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NzAxMjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NzAxMjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NzAxMjB9
# Processed page 141. persons in page: 500. kept so far: 59344. skipped (missing email/phone) so far: 11156. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NzA2MjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NzA2MjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NzA2MjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NzA2MjB9
# Processed page 142. persons in page: 500. kept so far: 59792. skipped (missing email/phone) so far: 11208. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NzExMjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NzExMjB9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NzExMjAsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NzExMjB9
# Processed page 143. persons in page: 500. kept so far: 60223. skipped (missing email/phone) so far: 11277. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NzE2MjEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NzE2MjF9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NzE2MjEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NzE2MjF9
# Processed page 144. persons in page: 500. kept so far: 60644. skipped (missing email/phone) so far: 11356. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NzIxMjEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NzIxMjF9
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6NzIxMjEsInNvcnREaXJlY3Rpb24iOiJhc2MiLCJpZCI6NzIxMjF9
# ...
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzQ3NTAyLCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM0NzUwMn0
# Processed page 695. persons in page: 500. kept so far: 298996. skipped (missing email/phone) so far: 48504. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzQ4MDAyLCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM0ODAwMn0
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzQ4MDAyLCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM0ODAwMn0
# Processed page 696. persons in page: 500. kept so far: 299369. skipped (missing email/phone) so far: 48631. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzQ4NTAyLCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM0ODUwMn0
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzQ4NTAyLCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM0ODUwMn0
# Processed page 697. persons in page: 500. kept so far: 299769. skipped (missing email/phone) so far: 48731. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzQ5MDAzLCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM0OTAwM30
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzQ5MDAzLCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM0OTAwM30
# Processed page 698. persons in page: 500. kept so far: 300138. skipped (missing email/phone) so far: 48862. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzQ5NTAzLCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM0OTUwM30
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzQ5NTAzLCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM0OTUwM30
# Processed page 699. persons in page: 500. kept so far: 300523. skipped (missing email/phone) so far: 48977. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzUwMDAzLCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1MDAwM30
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzUwMDAzLCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1MDAwM30
# Processed page 700. persons in page: 500. kept so far: 300961. skipped (missing email/phone) so far: 49039. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzUwNTAzLCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1MDUwM30
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzUwNTAzLCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1MDUwM30
# Processed page 701. persons in page: 500. kept so far: 301365. skipped (missing email/phone) so far: 49135. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzUxMDAzLCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1MTAwM30
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzUxMDAzLCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1MTAwM30
# Processed page 702. persons in page: 500. kept so far: 301769. skipped (missing email/phone) so far: 49231. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzUxNTA0LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1MTUwNH0
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzUxNTA0LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1MTUwNH0
# Processed page 703. persons in page: 500. kept so far: 302201. skipped (missing email/phone) so far: 49299. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzUyMDA0LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1MjAwNH0
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzUyMDA0LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1MjAwNH0
# Processed page 704. persons in page: 500. kept so far: 302639. skipped (missing email/phone) so far: 49361. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzUyNTA0LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1MjUwNH0
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzUyNTA0LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1MjUwNH0
# Processed page 705. persons in page: 500. kept so far: 303044. skipped (missing email/phone) so far: 49456. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzUzMDA0LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1MzAwNH0
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzUzMDA0LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1MzAwNH0
# Processed page 706. persons in page: 500. kept so far: 303458. skipped (missing email/phone) so far: 49542. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzUzNTA1LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1MzUwNX0
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzUzNTA1LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1MzUwNX0
# Processed page 707. persons in page: 500. kept so far: 303900. skipped (missing email/phone) so far: 49600. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzU0MDA1LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1NDAwNX0
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzU0MDA1LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1NDAwNX0
# Processed page 708. persons in page: 500. kept so far: 304311. skipped (missing email/phone) so far: 49689. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzU0NTA1LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1NDUwNX0
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzU0NTA1LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1NDUwNX0
# Processed page 709. persons in page: 500. kept so far: 304748. skipped (missing email/phone) so far: 49752. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzU1MDA3LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1NTAwN30
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzU1MDA3LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1NTAwN30
# Processed page 710. persons in page: 500. kept so far: 304904. skipped (missing email/phone) so far: 50096. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzU1NTA3LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1NTUwN30
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzU1NTA3LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1NTUwN30
# Processed page 711. persons in page: 500. kept so far: 305073. skipped (missing email/phone) so far: 50427. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzU2MDA3LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1NjAwN30
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzU2MDA3LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1NjAwN30
# Processed page 712. persons in page: 500. kept so far: 305234. skipped (missing email/phone) so far: 50766. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzU2NTA4LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1NjUwOH0
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzU2NTA4LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1NjUwOH0
# Processed page 713. persons in page: 500. kept so far: 305358. skipped (missing email/phone) so far: 51142. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzU3MDA4LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1NzAwOH0
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzU3MDA4LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1NzAwOH0
# Processed page 714. persons in page: 500. kept so far: 305535. skipped (missing email/phone) so far: 51465. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzU3NTA4LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1NzUwOH0
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzU3NTA4LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1NzUwOH0
# Processed page 715. persons in page: 500. kept so far: 305687. skipped (missing email/phone) so far: 51813. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzU4MDA4LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1ODAwOH0
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzU4MDA4LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1ODAwOH0
# Processed page 716. persons in page: 500. kept so far: 305861. skipped (missing email/phone) so far: 52139. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzU4NTA4LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1ODUwOH0
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzU4NTA4LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1ODUwOH0
# Processed page 717. persons in page: 500. kept so far: 306013. skipped (missing email/phone) so far: 52487. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzU5MDA4LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1OTAwOH0
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzU5MDA4LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1OTAwOH0
# Processed page 718. persons in page: 500. kept so far: 306185. skipped (missing email/phone) so far: 52815. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzU5NTA4LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1OTUwOH0
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzU5NTA4LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM1OTUwOH0
# Processed page 719. persons in page: 500. kept so far: 306499. skipped (missing email/phone) so far: 53001. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzYwMDA4LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2MDAwOH0
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzYwMDA4LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2MDAwOH0
# Processed page 720. persons in page: 500. kept so far: 306800. skipped (missing email/phone) so far: 53200. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzYwNTA5LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2MDUwOX0
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzYwNTA5LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2MDUwOX0
# Processed page 721. persons in page: 500. kept so far: 307162. skipped (missing email/phone) so far: 53338. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzYxMDA5LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2MTAwOX0
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzYxMDA5LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2MTAwOX0
# Processed page 722. persons in page: 500. kept so far: 307593. skipped (missing email/phone) so far: 53407. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzYxNTA5LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2MTUwOX0
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzYxNTA5LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2MTUwOX0
# Processed page 723. persons in page: 500. kept so far: 308035. skipped (missing email/phone) so far: 53465. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzYyMDA5LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2MjAwOX0
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzYyMDA5LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2MjAwOX0
# Processed page 724. persons in page: 500. kept so far: 308489. skipped (missing email/phone) so far: 53511. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzYyNTA5LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2MjUwOX0
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzYyNTA5LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2MjUwOX0
# Processed page 725. persons in page: 500. kept so far: 308941. skipped (missing email/phone) so far: 53559. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzYzMDA5LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2MzAwOX0
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzYzMDA5LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2MzAwOX0
# Processed page 726. persons in page: 500. kept so far: 309404. skipped (missing email/phone) so far: 53596. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzYzNTA5LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2MzUwOX0
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzYzNTA5LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2MzUwOX0
# Processed page 727. persons in page: 500. kept so far: 309843. skipped (missing email/phone) so far: 53657. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzY0MDA5LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2NDAwOX0
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzY0MDA5LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2NDAwOX0
# Processed page 728. persons in page: 500. kept so far: 310296. skipped (missing email/phone) so far: 53704. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzY0NTEwLCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2NDUxMH0
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzY0NTEwLCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2NDUxMH0
# Processed page 729. persons in page: 500. kept so far: 310754. skipped (missing email/phone) so far: 53746. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzY1MDExLCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2NTAxMX0
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzY1MDExLCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2NTAxMX0
# Processed page 730. persons in page: 500. kept so far: 311204. skipped (missing email/phone) so far: 53796. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzY1NTExLCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2NTUxMX0
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzY1NTExLCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2NTUxMX0
# Processed page 731. persons in page: 500. kept so far: 311657. skipped (missing email/phone) so far: 53843. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzY2MDEzLCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2NjAxM30
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzY2MDEzLCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2NjAxM30
# Processed page 732. persons in page: 500. kept so far: 312092. skipped (missing email/phone) so far: 53908. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzY2NTEzLCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2NjUxM30
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzY2NTEzLCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2NjUxM30
# Processed page 733. persons in page: 500. kept so far: 312532. skipped (missing email/phone) so far: 53968. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzY3MDEzLCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2NzAxM30
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzY3MDEzLCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2NzAxM30
# Processed page 734. persons in page: 500. kept so far: 312973. skipped (missing email/phone) so far: 54027. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzY3NTE0LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2NzUxNH0
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzY3NTE0LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2NzUxNH0
# Processed page 735. persons in page: 500. kept so far: 313413. skipped (missing email/phone) so far: 54087. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzY4MDE0LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2ODAxNH0
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzY4MDE0LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2ODAxNH0
# Processed page 736. persons in page: 500. kept so far: 313771. skipped (missing email/phone) so far: 54229. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzY4NTE0LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2ODUxNH0
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzY4NTE0LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2ODUxNH0
# Processed page 737. persons in page: 500. kept so far: 314055. skipped (missing email/phone) so far: 54445. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzY5MDE0LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2OTAxNH0
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzY5MDE0LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2OTAxNH0
# Processed page 738. persons in page: 500. kept so far: 314509. skipped (missing email/phone) so far: 54491. next_cursor: eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzY5NTE0LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2OTUxNH0
# Requesting up to 500 persons. cursor=eyJmaWVsZCI6ImlkIiwiZmllbGRWYWx1ZSI6MzY5NTE0LCJzb3J0RGlyZWN0aW9uIjoiYXNjIiwiaWQiOjM2OTUxNH0
# Processed page 739. persons in page: 40. kept so far: 314545. skipped (missing email/phone) so far: 54495. next_cursor: None
# No next_cursor. reached final page.
#
# === DONE ===
# Total persons returned by API: 369040
# Total kept (both email and phone present): 314545
# Total dropped (missing email or phone): 54495
# CSV written to: /Users/abhishek/pipedrive_contacts_all.csv
# {'email': 'prabhatkumar33200@gmail.com', 'phone': '+918521225200', 'phone_country': 'India'}
# {'email': 'stetoc37@gmail.com', 'phone': '+48723717522', 'phone_country': 'Poland'}
# {'email': 'blackswan123@yopmail.com', 'phone': '+917276253478', 'phone_country': 'India'}
# {'email': 'stetoc37@gmail.com', 'phone': '+48723717522', 'phone_country': 'Poland'}
# {'email': 'iamfx908@gmail.com', 'phone': '+639060369185', 'phone_country': 'Philippines'}
